# %% [markdown]
# Removing the Unwanted values from the Dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/GSE63602_DESeq_results.xlsx')
df.head()
df.sample(5)
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#           id      baseMean    baseMeanA     baseMeanB  foldChange  \
# 3086  DDX19B    492.025602   609.406947    439.856115    0.721777
# 7813  NBEAL2  10939.688728  3056.692605  14443.242561    4.725121
# 2558   CNNM2    727.262004   277.509792    927.151876    3.340970
# 3859  EXOSC5    339.644396   308.952211    353.285367    1.143495
# 5408    IARS   7551.558093  6463.870702   8034.974711    1.243059
#
#       log2FoldChange          pval          padj
# 3086       -0.470374  1.988417e-01  3.699221e-01
# 7813        2.240351  3.607593e-14  9.470271e-13
# 2558        1.740267  2.866079e-07  2.987115e-06
# 3859        0.193450  6.090094e-01  7.646984e-01
# 5408        0.313895  2.760439e-01  4.644800e-01

# %%
df.info()
rows= len(df)
print(rows)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14018 entries, 0 to 14017
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              14018 non-null  object
#  1   baseMean        14018 non-null  float64
#  2   baseMeanA       14018 non-null  float64
#  3   baseMeanB       14018 non-null  float64
#  4   foldChange      14018 non-null  float64
#  5   log2FoldChange  14017 non-null  float64
#  6   pval            14018 non-null  float64
#  7   padj            14018 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 876.3+ KB
# 14018

# %% [markdown]
# Now I am going to reduce the dataset based on 2 conditions:
#
# Basemean >=10 this removes extremely low-expressed genes
# padj <0.1 helps us keep only statistically significant genes.

# %%
filtered_genes = df[ (df['padj']<0.1) & (df['baseMean'] >=10)]
filtered_genes.to_csv("filtered_genes.csv", index=False)

# %%
main = pd.read_csv('/content/filtered_genes.csv')
rows1 = len(main)
print(rows1)
# Out:
# 4883
